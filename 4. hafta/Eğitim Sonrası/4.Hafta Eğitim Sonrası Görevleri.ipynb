# %% [markdown]
# # Problem 1
# `ogrenciler` adında bir sözlük oluşturunuz. Kullanıcıdan döngü yardımıyla 3 öğrenci için veri girmesini isteyerek öğrencilerin sırasıyla okul numarası, isim, soy isim, telefon numarası ve doğum tarihi bilgilerini alınız. Aldığınız öğrenci bilgilerini yine aynı döngü yardımıyla `ogrenciler` adındaki sözlükte saklayınız. Daha sonra öğrenci bilgilerinin bulunduğu sözlük yapısını ekrana bastırınız.

# %%
ogrenciler = {}

for i in range(1,4):
    print(f"\n{i}. Öğrenci bilgileri:")

    okul_numarasi = input("Okul numarası:")
    isim = input("isim:")
    soy_isim = input("soyisim:")
    telefon_numarasi = input("telefon numarasi:")
    dogum_tarihi = input("doğum tarihi:")

ogrenci_bilgileri= {
    "Okul numarası" okul_numarasi,
    "isim": isim,
    "soyisim": soy_isim,
    "telefon numarası": telefon_numarasi,
    "doğum tarihi": dogum_tarihi
}

ogrenciler[f"öğrenci {i}"] = ogrenci_bilgileri

print("\nÖğrenci Bilgileri:")
for ogrenci, bilgiler in ogrenciler.items():
    print(f"\n{ogrenci}:")
    for anahtar, deger in bilgiler.items():
        print(f"{anahtar}: {deger}")
# Out:
#   Cell In[3], line 13
#     "Okul numarası" okul_numarasi,
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# # Problem 2
#
# ### a - Biraz ısınarak başlayalım!
#
# ```
# numbers = [5,10,10,15,15,15,20,20,20,20]
# ```
#
# Yukarıda `numbers` adında 10 elemanlı bir liste verilmiştir. Bu listenin her elemanını kontrol eden ve tekrar eden elemanları bir kez olacak şekilde başka bir listeye kopyalayan bir program yazınız. Son olarak oluşturduğunuz listeyi ekrana bastırınız.
#
#
#
#
# ```
# >Output
# [5, 10, 15, 20]
# ```

# %%
numbers = [5, 10, 10, 15, 15, 15, 20, 20, 20, 20]


unique_numbers = []


for number in numbers:
    if number not in unique_numbers:
        unique_numbers.append(number)


print(unique_numbers)

# %% [markdown]
# ### 🌶️ b) Hadi işi biraz daha zorlaştıralım!
#
#
# Şimdiyse senden `numbers` isimli listedeki tekrar eden elemanları `repeatNumbers` adındaki listeye; tekrar etmeyen elemanları `uniqueNumbers`adındaki listeye kopyalayan yazmanı ve listeleri ekrana bastırmanı bekliyoruz
#
# ```
# >Output
# Tekrar Eden Elemanlar: [10, 10, 15, 15, 15, 20, 20, 20, 20]
# Tekrar Etmeyen Elemanlar: [5]
# ```

# %%
numbers = [10,20,15,5,10,20,15,20,15,20,10,20]

repeatNumbers = []
uniqueNNumbers = []

from collections import Counter
count = Counter(numbers)

for num, freq in count.items():
    if freq > 1:
        repeatNumbers.extent([num] * freq)
    else:
        uniqueNumber.append(num)

print("Tekrar eden elemanlar:", repeatNumbers)
print("Tekrar etmeyen elemanlar:, uniqueNumbers")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 11
#       9 for num, freq in count.items():
#      10     if freq > 1:
# ---> 11         repeatNumbers.extent([num] * freq)
#      12     else:
#      13         uniqueNumber.append(num)
#
# AttributeError: 'list' object has no attribute 'extent'

# %% [markdown]
# # Problem 3
# sn1 = {1,2,3,4,5}
#
# sn2 = {4,5,6,7,8}
#
#  Verilen 2 adet küme için kesişimlerini, farklarını ve birleşimlerini bulunuz.

# %%
sn1 = {1,2,3,4,5}
sn2 = {4,5,6,7,8}

kesisim = sn1.intersection(sn2)
fark_sn1_sn2 = sn1.difference(sn2)
fark_sn2_sn1 = sn2.difference(sn1)
birlesim = sn1.union(sn2)

print("Kesişim:" , kesisim)
print("sn1'de olup sn2'de olmayanlar:" , fark_sn1_sn2_sn1_sn2)

print("sn2'de olup sn1'de olmayanlar:" , fark_sn1_sn2_sn2_sn1)
print("Birleşim:", birlesim )
# Out:
# Kesişim: {4, 5}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       7 birlesim = sn1.union(sn2)
#       9 print("Kesişim:" , kesisim)
# ---> 10 print("sn1'de olup sn2'de olmayanlar:" , fark_sn1_sn2_sn1_sn2)
#      12 print("sn2'de olup sn1'de olmayanlar:" , fark_sn1_sn2_sn2_sn1)
#      13 print("Birleşim:", birlesim )
#
# NameError: name 'fark_sn1_sn2_sn1_sn2' is not defined

# %% [markdown]
# # Problem 4
#
# Buradaki işlemlerimizin tamamı stringler içindir. Aşağıda verilecek olan metodlar için kendinizin örnek yaratması gerekmektedir.
#
# Örneğin `upper` için `string` değişkeni oluştururken` k = "BAC"` şeklinde oluşturmayınız. Bunun yerine k değişkenini `k = "bac`" şeklinde oluşturmanız `upper` metodundaki değişimi görebilmeniz için daha iyi olacaktır.
#
# Bütün metodlardaki değişimin gözle görülür şekilde değişimi beklenmektedir.
#
#
# 1- capitalize(), lower(), upper(), swapcase(), title(), replace()
#
# 2- endswith(), startswith(), find(), index(), count()
#
# 3- split(), strip(), join(), islower(), isalpha(), isdigit()
#
#
# Yukarıdaki `string` metodlarındaki değişimleri görebildiğimiz bir program yazınız.

# %%
#1

example = "hello world"
print("capitalize():", example.capitalize() )
print("lower():", example.lower())
print("upper()", example.upper())
print("swapcase():", example.swapcase())
print("title():", example.title())
print("replace()", example.replace())

#2

print("startswith('hello')", example.startswith("hello") )
print("endswith('world')" , example.endswith("world"))
print("find('r'):" , example.find("r"))
print("index('r')", example.index("r"))
print("count('l'):", example.count("l"))
# Out:
# capitalize(): Hello world
# lower(): hello world
# upper() HELLO WORLD
# swapcase(): HELLO WORLD
# title(): Hello World
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       7 print("swapcase():", example.swapcase())
#       8 print("title():", example.title())
# ----> 9 print("replace()", example.replace())
#      11 #2
#      13 print("startswith('hello')", example.startswith("hello") )
#
# TypeError: replace expected at least 2 arguments, got 0
